# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
import os
import yaml
import warnings
from crewai import Agent, Task, Crew

# Load environment variables
from dotenv import load_dotenv
load_dotenv("F:\Social AI\multiagent-framework\.venv\.env")

# Warning control
warnings.filterwarnings('ignore')

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Website Project Requirements Breakdown**
#
# **Project Overview:**
# The goal of this project is to create a responsive and user-friendly website for a small business that effectively showcases its offerings, enhances its online presence, and engages its customers.
#
# ### Breakdown of Project Tasks
#
# 1. **Create a Responsive Design**
#    - **Description**: Design a website layout that adapts to different screen sizes (desktop, tablet, mobile).
#    - **Scope**: Includes wireframing and prototyping.
#    - **Timeline**: 2 weeks
#    - **Dependencies**: Must be completed before UI Implementation.
#    - **Deliverables**: Wireframes and responsive design mockups.
#
# 2. **Implement Modern User Interface**
#    - **Description**: Develop a visually appealing user interface adhering to modern design principles.
#    - **Scope**: Focus on colors, typography, and imagery.
#    - **Timeline**: 3 weeks (concurrent with Responsive Design)
#    - **Dependencies**: Completion of design phase.
#    - **Deliverables**: UI components and style guides.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Description**: Design an intuitive menu structure that enhances user experience.
#    - **Scope**: Vertical/horizontal menus, dropdown functionalities.
#    - **Timeline**: 1 week
#    - **Dependencies**: Completion of UI Implementation.
#    - **Deliverables**: Navigation wireframe and prototype.
#
# 4. **Create an "About Us" Page**
#    - **Description**: Page that details the company's history, mission, and values.
#    - **Scope**: Content creation and layout design.
#    - **Timeline**: 1 week
#    - **Dependencies**: Completion of initial design phase.
#    - **Deliverables**: Completed "About Us" page content and layout.
#
# 5. **Design a "Services" Page**
#    - **Description**: Showcase and describe the services offered by the business.
#    - **Scope**: Content and image selection.
#    - **Timeline**: 1 week
#    - **Dependencies**: Content finalization.
#    - **Deliverables**: Completed "Services" page content and design.
#
# 6. **Create a "Contact Us" Page**
#    - **Description**: Develop a page with a contact form, integrated map, and contact details.
#    - **Scope**: Backend implementation for form submission.
#    - **Timeline**: 1 week
#    - **Dependencies**: UI Completion.
#    - **Deliverables**: Completed contact form and interactive map implementation.
#
# 7. **Implement Blog Section**
#    - **Description**: Set up a blog section for sharing updates and industry news.
#    - **Scope**: Design templates and backend setup.
#    - **Timeline**: 2 weeks
#    - **Dependencies**: Completion of core site design.
#    - **Deliverables**: Blog template and post creation functionality.
#
# 8. **Optimize for Fast Loading and SEO**
#    - **Description**: Ensure website speeds are optimized and SEO best practices are implemented.
#    - **Scope**: Image optimization, coding standards, and meta tags.
#    - **Timeline**: 1 week
#    - **Dependencies**: Completion of website development.
#    - **Deliverables**: Optimized website and SEO report.
#
# 9. **Integrate Social Media Links**
#    - **Description**: Add social media icons/links to the website.
#    - **Scope**: Link to all business social media profiles.
#    - **Timeline**: 1 week
#    - **Dependencies**: Completion of website design.
#    - **Deliverables**: Social media buttons and links functional.
#
# 10. **Include Testimonials Section**
#    - **Description**: A section for customer feedback and reviews.
#    - **Scope**: Design, content gathering, and layout.
#    - **Timeline**: 1 week
#    - **Dependencies**: Successful completion of other page designs.
#    - **Deliverables**: Testimonials page with review submission feature.
#
# ### Project Timeline Visualization (Gantt Chart)
#
# | Task                          | Duration      | Start Date | End Date   | Dependencies                                |
# |-------------------------------|---------------|------------|------------|---------------------------------------------|
# | Create Responsive Design       | 2 weeks       | Week 1     | Week 2     | None                                        |
# | Implement User Interface       | 3 weeks       | Week 1     | Week 3     | Create Responsive Design                    |
# | Develop Navigation System      | 1 week        | Week 4     | Week 4     | Implement User Interface                     |
# | Create "About Us" Page       | 1 week        | Week 4     | Week 4     | UI Implementation                            |
# | Design "Services" Page        | 1 week        | Week 5     | Week 5     | Create "About Us" Page                     |
# | Create "Contact Us" Page      | 1 week        | Week 5     | Week 5     | UI Completion                               |
# | Implement Blog Section         | 2 weeks       | Week 6     | Week 7     | Completion of core site design              |
# | Optimize for Speed and SEO    | 1 week        | Week 8     | Week 8     | Completion of website development            |
# | Integrate Social Media Links   | 1 week        | Week 8     | Week 8     | Website design completion                    |
# | Include Testimonials Section    | 1 week        | Week 9     | Week 9     | Completion of other page designs             |
#
# ### Team Assignments
#
# - **John Doe (Project Manager)**: Overall project oversight and coordination.
# - **Jane Doe (Software Engineer)**: Backend development, including implementation of contact forms and blog functionality.
# - **Bob Smith (Designer)**: UI/UX Design, mockups, and prototypes.
# - **Alice Johnson (QA Engineer)**: Testing for functionality and usability.
# - **Tom Brown (QA Engineer)**: Performance testing and SEO optimization.
#
# **Outcome:** Upon the completion of this detailed planning phase, the team will have a clear, organized framework for executing each segment of the project, ensuring all goals align strategically with the business's needs, ultimately delivering a robust and engaging website on time and within the defined scope.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### Task Evaluations
#
# 1. **Create a Responsive Design**
#    - **Estimated Time**: 2 weeks
#    - **Resources Required**:
#      - 1 UI/UX Designer (Bob Smith)
#    - **Effort**: 80 hours
#    - **Risks/Uncertainties**: Potential revisions from stakeholders could delay the timeline.
#
# 2. **Implement Modern User Interface**
#    - **Estimated Time**: 3 weeks (concurrent with Responsive Design)
#    - **Resources Required**:
#      - 1 UI/UX Designer (Bob Smith)
#      - 1 Frontend Developer (optional assistance for implementation)
#    - **Effort**: 120 hours
#    - **Risks/Uncertainties**: Design alignment issues with the responsive design; possible iterations based on feedback.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Estimated Time**: 1 week
#    - **Resources Required**:
#      - 1 Frontend Developer
#    - **Effort**: 40 hours
#    - **Risks/Uncertainties**: User testing may reveal navigation challenges that require further adjustments.
#
# 4. **Create an "About Us" Page**
#    - **Estimated Time**: 1 week
#    - **Resources Required**:
#      - 1 Content Creator (unless available within the team)
#      - 1 Frontend Developer
#    - **Effort**: 40 hours
#    - **Risks/Uncertainties**: Difficulty in gathering authentic content or approval from stakeholders could impact timelines.
#
# 5. **Design a "Services" Page**
#    - **Estimated Time**: 1 week
#    - **Resources Required**:
#      - 1 Content Creator
#      - 1 Frontend Developer
#    - **Effort**: 40 hours
#    - **Risks/Uncertainties**: Similar to the "About Us" page. Content approval may delay the design process.
#
# 6. **Create a "Contact Us" Page**
#    - **Estimated Time**: 1 week
#    - **Resources Required**:
#      - 1 Backend Developer (Jane Doe)
#      - 1 Frontend Developer
#    - **Effort**: 40 hours
#    - **Risks/Uncertainties**: Integration challenges with the map API or contact form could delay this task.
#
# 7. **Implement Blog Section**
#    - **Estimated Time**: 2 weeks
#    - **Resources Required**:
#      - 1 Backend Developer (Jane Doe)
#      - 1 Frontend Developer
#    - **Effort**: 80 hours
#    - **Risks/Uncertainties**: Technical difficulties in back-end integration or template design could lead to extended timelines.
#
# 8. **Optimize for Fast Loading and SEO**
#    - **Estimated Time**: 1 week
#    - **Resources Required**:
#      - 1 QA Engineer (Tom Brown) for performance testing
#      - 1 Frontend Developer
#    - **Effort**: 40 hours
#    - **Risks/Uncertainties**: SEO issues may arise during testing, requiring additional fixes, which could affect project scope.
#
# 9. **Integrate Social Media Links**
#    - **Estimated Time**: 1 week
#    - **Resources Required**:
#      - 1 Frontend Developer
#    - **Effort**: 20 hours
#    - **Risks/Uncertainties**: Missing or incorrect social media URLs could cause rework.
#
# 10. **Include Testimonials Section**
#     - **Estimated Time**: 1 week
#     - **Resources Required**:
#       - 1 Content Creator
#       - 1 Frontend Developer
#     - **Effort**: 40 hours
#     - **Risks/Uncertainties**: Gathering sufficient testimonials may be a challenge; may lead to adjustments in layout/design.
#
# #### Summary
#
# **Total Estimated Duration**: Approximately 11 weeks from start to completion, accounting for concurrent tasks.
# **Total Team Effort**: Approximately 520 hours across all tasks.
#
# #### Risks Summary
#
# - **Content Delays**: Gathering content can lead to approval delays, particularly for the "About Us" and "Services" pages.
# - **Design Revisions**: Changes to the UI/UX based on stakeholder feedback might extend timelines.
# - **Technology Integration Issues**: Potential problems in backend setup or third-party API integration may disrupt the schedule.
# - **SEO Optimization**: Unexpected SEO challenges discovered during performance testing could require additional effort.
#
# **Conclusion**: This detailed estimation report provides insights into the resources required, time allocations, and potential risks for the Website project. By being proactive in addressing these uncertainties, the team can navigate challenges effectively, ensuring a smooth development process and timely delivery.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                   | Team Member(s)           | Start Date | End Date   | Duration   |
# |----------------------------------------|--------------------------|------------|------------|------------|
# | Create a Responsive Design             | Bob Smith                | 01/01/2024 | 14/01/2024 | 2 weeks    |
# | Implement Modern User Interface        | Bob Smith                | 01/01/2024 | 21/01/2024 | 3 weeks    |
# | Develop User-Friendly Navigation System | Jane Doe                 | 01/01/2024 | 07/01/2024 | 1 week     |
# | Create an "About Us" Page             | Jane Doe & Bob Smith     | 08/01/2024 | 14/01/2024 | 1 week     |
# | Design a "Services" Page              | Jane Doe & Bob Smith     | 15/01/2024 | 21/01/2024 | 1 week     |
# | Create a "Contact Us" Page            | Jane Doe                 | 22/01/2024 | 28/01/2024 | 1 week     |
# | Implement Blog Section                 | Jane Doe & Bob Smith     | 29/01/2024 | 11/02/2024 | 2 weeks    |
# | Optimize for Fast Loading and SEO      | Tom Brown & Bob Smith     | 12/02/2024 | 18/02/2024 | 1 week     |
# | Integrate Social Media Links           | Jane Doe                 | 19/02/2024 | 25/02/2024 | 1 week     |
# | Include Testimonials Section            | Jane Doe & Bob Smith     | 26/02/2024 | 03/03/2024 | 1 week     |
#
# ### Summary of Allocation Decisions
#
# 1. **Create a Responsive Design**: Assigned to Bob Smith, the UI/UX Designer, as this task requires specialized design skills and his availability matches the project's timeline.
#
# 2. **Implement Modern User Interface**: Bob Smith is responsible for this task, as well. Implementing the UI is best suited to him given the concurrent timeline with the responsive design, allowing him to leverage his work efficiently.
#
# 3. **Develop User-Friendly Navigation System**: Assigned to Jane Doe, who is capable of frontend development tasks. Her expertise allows for the creation of effective navigation while keeping her workload balanced.
#
# 4. **Create an "About Us" Page**: Assigned to both Jane Doe and Bob Smith. This task requires both a developer’s touch and design capabilities, and both team members are available and skilled.
#
# 5. **Design a "Services" Page**: Again, assigned to Jane Doe and Bob Smith for the same reason as the "About Us" page to ensure a cohesive design and development approach.
#
# 6. **Create a "Contact Us" Page**: Managed by Jane Doe alone, since the backend component (if needed) is usually aligned with her skills, and the frontend elements can be added later by Bob, keeping balance in their workload.
#
# 7. **Implement Blog Section**: This task also requires both Jane Doe for backend integration and Bob Smith for frontend interaction, leveraging their simultaneous efforts throughout this spring window.
#
# 8. **Optimize for Fast Loading and SEO**: Assigned to Tom Brown and Bob Smith, with Tom focusing on QA aspects for performance. This task is crucial and benefits from the combined skills of both as they address optimization challenges.
#
# 9. **Integrate Social Media Links**: Tasked to Jane Doe utilizing her backend capabilities, as the links will require backend data integration; her balanced workload allows for completion.
#
# 10. **Include Testimonials Section**: This further balances our team by assigning it to Jane Doe and Bob Smith, as gathering testimonials could require creative input from Bob alongside her task as a developer.
#
# ### Conclusion
#
# Overall, the resource allocation is designed to ensure team members' skills are matched to tasks they are best suited for, and availability is respected to minimize overburdening. Strategic assignment allows for effective collaboration and maximizes the project's potential for timely success. Each task's durations reflect a manageable workload for each team member, aligning their efforts toward the shared goal of a successful website project completion by the projected end date.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0012
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          8098           4567                     0               3531
#
#    successful_requests
# 0                    4

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement Modern User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop User-Friendly Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create an "About Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Design a "Services" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Create a "Contact Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']},
#   {'task_name': 'Optimize for Fast Loading and SEO',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Tom Brown', 'Bob Smith']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Bob Smith']}],
#  'milestones': [{'milestone_name': 'Website Design Completion',
#    'tasks': ['Create a Responsive Design',
#     'Implement Modern User Interface',
#     'Develop User-Friendly Navigation System',
#     'Create an "About Us" Page',
#     'Design a "Services" Page']},
#   {'milestone_name': 'Website Development Completion',
#    'tasks': ['Create a "Contact Us" Page', 'Implement Blog Section']},
#   {'milestone_name': 'Final Review and Optimization',
#    'tasks': ['Optimize for Fast Loading and SEO',
#     'Integrate Social Media Links',
#     'Include Testimonials Section']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_478f2 th {
#   font-size: 120%;
# }
# #T_478f2  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_478f2" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_478f2_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_478f2_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_478f2_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_478f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_478f2_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_478f2_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_478f2_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_478f2_row1_col0" class="data row1 col0" >Implement Modern User Interface</td>
#       <td id="T_478f2_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_478f2_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_478f2_row2_col0" class="data row2 col0" >Develop User-Friendly Navigation System</td>
#       <td id="T_478f2_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_478f2_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_478f2_row3_col0" class="data row3 col0" >Create an "About Us" Page</td>
#       <td id="T_478f2_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_478f2_row3_col2" class="data row3 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_478f2_row4_col0" class="data row4 col0" >Design a "Services" Page</td>
#       <td id="T_478f2_row4_col1" class="data row4 col1" >40.000000</td>
#       <td id="T_478f2_row4_col2" class="data row4 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_478f2_row5_col0" class="data row5 col0" >Create a "Contact Us" Page</td>
#       <td id="T_478f2_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_478f2_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_478f2_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_478f2_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_478f2_row6_col2" class="data row6 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_478f2_row7_col0" class="data row7 col0" >Optimize for Fast Loading and SEO</td>
#       <td id="T_478f2_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_478f2_row7_col2" class="data row7 col2" >['Tom Brown', 'Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_478f2_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_478f2_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_478f2_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_478f2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_478f2_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_478f2_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_478f2_row9_col2" class="data row9 col2" >['Jane Doe', 'Bob Smith']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_0567d th {
#   font-size: 120%;
# }
# #T_0567d  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_0567d" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0567d_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_0567d_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0567d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0567d_row0_col0" class="data row0 col0" >Website Design Completion</td>
#       <td id="T_0567d_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement Modern User Interface', 'Develop User-Friendly Navigation System', 'Create an "About Us" Page', 'Design a "Services" Page']</td>
#     </tr>
#     <tr>
#       <th id="T_0567d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0567d_row1_col0" class="data row1 col0" >Website Development Completion</td>
#       <td id="T_0567d_row1_col1" class="data row1 col1" >['Create a "Contact Us" Page', 'Implement Blog Section']</td>
#     </tr>
#     <tr>
#       <th id="T_0567d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0567d_row2_col0" class="data row2 col0" >Final Review and Optimization</td>
#       <td id="T_0567d_row2_col1" class="data row2 col1" >['Optimize for Fast Loading and SEO', 'Integrate Social Media Links', 'Include Testimonials Section']</td>
#     </tr>
#   </tbody>
# </table>
